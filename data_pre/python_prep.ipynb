# %% [markdown]
# ### Find Duplicate Elements in a List

# %%
nums = [1,2,3,4,2,5,3,6]
no_dub = set()
dubli = set()
for i in nums:
    if i not in dubli:
        dubli.add(i)
    else:
        no_dub.add(i)
print(list(dubli))
print(list(no_dub))

# %% [markdown]
# ### Count Frequency of Elements in a List

# %%
nums = [1,2,2,3,3,3,4]
freq = {}
for n in nums:
    freq[n] = freq.get(n, 0) + 1
print(freq)

# %% [markdown]
# ### Find the Second Largest Number

# %%
nums = [10, 20, 4, 45, 99]
num1 = list(set(nums))
num1.sort(reverse=True)
print(num1[1])
print(num1)

# %% [markdown]
# ### Reverse a String

# %%
text = "dataengineering"
reverserd_text = text[::-1]
print(reverserd_text)

# %% [markdown]
# ### Check if a String is a Palindrome

# %%
word = "level"
reverserd_word = word[::-1]
print(reverserd_word)
def is_palindrome(word):
    return word == word[::-1]
word = "level"
print(is_palindrome(word))

# %%
from pyspark.sql.types import *

schema = StructType([
    StructField("order_id", IntegerType(), True),
    StructField("customer_id", IntegerType(), True),
    StructField("order_value", DoubleType(), True)
])

df = spark.read \
    .option("header", True) \
    .schema(schema) \
    .csv("/path/orders.csv")

# %% [markdown]
# ### Find Frequency of Each Element

# %%
nums = [1, 2, 2, 3, 3, 3]
frequence = {}
for n in nums:
    frequence[n] = frequence.get(n,0) + 1
print(frequence)

# %% [markdown]
# ### Find First Non-Repeating Character

# %%
from collections import Counter

s = "swiss"

count = Counter(s)
for char in s:
    if count[char] == 1:
        print(char)
        break

# %% [markdown]
# ### Reverse a String

# %%
s = "hello"

reverse = s[::-1]

print(reverse)

# %% [markdown]
# ### Check Whether a String is a Palindrome

# %%
import re

s = "A man, a plan! a canal: Panama"

# Remove special characters, spaces, punctuation
cleaned = re.sub(r'[^a-zA-Z0-9]', '', s).lower()
print(cleaned)
# Check palindrome
if cleaned == cleaned[::-1]:
    print("Palindrome")
else:
    print("Not a Palindrome")

# %% [markdown]
# ### Find Second-Largest Number

# %%
nums = [10, 20, 5, 30, 30, 15]
nums = list(set(nums))
nums.sort()
a = nums[-2]
print(a)

# %% [markdown]
# ### Find Common Elements Between Two Lists

# %%
list1 = [1, 2, 3, 4]
list2 = [3, 4, 5, 6]

com = list(set(list1) & set(list2))
print(com)

# %% [markdown]
# ### Sort a Dictionary by Values

# %%
data = {
    "A": 50,
    "B": 20,
    "C": 80
}

# %%
sort_data = dict(sorted(data.items(), key=lambda x: x[1]))
print(sort_data)
